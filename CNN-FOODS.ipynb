# %% [markdown]
# <a href="https://colab.research.google.com/github/McATung/AI/blob/main/CNN-FOODS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
model = Sequential()
model.add(Conv2D(128,(3,3),input_shape=(256,256,3),activation = 'relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32,(3,3),activation = 'relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(128,activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(10,activation ='softmax'))
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 128)     3584
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 128)    0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      36896
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 123008)            0
#
#  dense (Dense)               (None, 128)               15745152
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 15,786,922
# Trainable params: 15,786,922
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %cd "/content/drive/MyDrive/MONAN"
# Out:
# /content/drive/MyDrive/MONAN

# %%
# %ls
# Out:
# 1/  TEST/  TRAICAY.h5  TRAIN/

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

# %%
training_set=train_datagen.flow_from_directory('/content/drive/MyDrive/MONAN/TRAIN',target_size=(256,256),batch_size=32,class_mode='categorical')
# Out:
# Found 270 images belonging to 10 classes.

# %%
test_set=train_datagen.flow_from_directory('/content/drive/MyDrive/MONAN/TEST',target_size=(256,256),batch_size=32,class_mode='categorical')
# Out:
# Found 216 images belonging to 10 classes.

# %%
history=model.fit(training_set,epochs=30,validation_data=test_set,verbose=1)
# Out:
# Epoch 1/30
# 9/9 [==============================] - 148s 17s/step - loss: 4.3371 - accuracy: 0.1074 - val_loss: 2.3018 - val_accuracy: 0.1574
# Epoch 2/30
# 9/9 [==============================] - 73s 8s/step - loss: 2.2996 - accuracy: 0.1222 - val_loss: 2.2960 - val_accuracy: 0.0926
# Epoch 3/30
# 9/9 [==============================] - 73s 8s/step - loss: 2.2850 - accuracy: 0.1630 - val_loss: 2.2721 - val_accuracy: 0.2546
# Epoch 4/30
# 9/9 [==============================] - 73s 8s/step - loss: 2.2769 - accuracy: 0.1556 - val_loss: 2.1960 - val_accuracy: 0.2778
# Epoch 5/30
# 9/9 [==============================] - 77s 9s/step - loss: 2.2244 - accuracy: 0.2704 - val_loss: 2.1789 - val_accuracy: 0.2731
# Epoch 6/30
# 9/9 [==============================] - 74s 8s/step - loss: 2.0762 - accuracy: 0.2630 - val_loss: 1.7797 - val_accuracy: 0.3935
# Epoch 7/30
# 9/9 [==============================] - 74s 9s/step - loss: 1.8706 - accuracy: 0.3407 - val_loss: 1.6881 - val_accuracy: 0.4120
# Epoch 8/30
# 9/9 [==============================] - 74s 9s/step - loss: 1.7520 - accuracy: 0.3852 - val_loss: 1.6371 - val_accuracy: 0.5185
# Epoch 9/30
# 9/9 [==============================] - 74s 8s/step - loss: 1.5881 - accuracy: 0.4778 - val_loss: 1.2379 - val_accuracy: 0.5648
# Epoch 10/30
# 9/9 [==============================] - 74s 8s/step - loss: 1.5323 - accuracy: 0.5111 - val_loss: 1.3169 - val_accuracy: 0.6667
# Epoch 11/30
# 9/9 [==============================] - 74s 8s/step - loss: 1.5328 - accuracy: 0.5259 - val_loss: 1.2957 - val_accuracy: 0.5370
# Epoch 12/30
# 9/9 [==============================] - 74s 8s/step - loss: 1.1967 - accuracy: 0.6000 - val_loss: 0.8414 - val_accuracy: 0.7222
# Epoch 13/30
# 9/9 [==============================] - 77s 9s/step - loss: 1.0166 - accuracy: 0.6481 - val_loss: 0.7215 - val_accuracy: 0.7963
# Epoch 14/30
# 9/9 [==============================] - 74s 8s/step - loss: 0.8443 - accuracy: 0.7148 - val_loss: 0.5833 - val_accuracy: 0.8056
# Epoch 15/30
# 9/9 [==============================] - 75s 8s/step - loss: 0.8058 - accuracy: 0.7407 - val_loss: 0.6369 - val_accuracy: 0.7870
# Epoch 16/30
# 9/9 [==============================] - 74s 9s/step - loss: 0.7499 - accuracy: 0.7889 - val_loss: 0.5816 - val_accuracy: 0.8287
# Epoch 17/30
# 9/9 [==============================] - 75s 9s/step - loss: 0.7007 - accuracy: 0.7704 - val_loss: 0.3629 - val_accuracy: 0.9074
# Epoch 18/30
# 9/9 [==============================] - 75s 8s/step - loss: 0.7106 - accuracy: 0.7963 - val_loss: 0.6012 - val_accuracy: 0.7917
# Epoch 19/30
# 9/9 [==============================] - 74s 8s/step - loss: 0.6619 - accuracy: 0.7815 - val_loss: 0.4430 - val_accuracy: 0.8889
# Epoch 20/30
# 9/9 [==============================] - 74s 9s/step - loss: 0.5067 - accuracy: 0.8519 - val_loss: 0.2861 - val_accuracy: 0.9398
# Epoch 21/30
# 9/9 [==============================] - 79s 9s/step - loss: 0.5038 - accuracy: 0.8481 - val_loss: 0.3385 - val_accuracy: 0.9259
# Epoch 22/30
# 9/9 [==============================] - 75s 8s/step - loss: 0.3706 - accuracy: 0.8852 - val_loss: 0.1991 - val_accuracy: 0.9630
# Epoch 23/30
# 9/9 [==============================] - 75s 8s/step - loss: 0.3219 - accuracy: 0.9000 - val_loss: 0.1820 - val_accuracy: 0.9676
# Epoch 24/30
# 9/9 [==============================] - 92s 11s/step - loss: 0.3709 - accuracy: 0.8926 - val_loss: 0.2161 - val_accuracy: 0.9444
# Epoch 25/30
# 9/9 [==============================] - 80s 9s/step - loss: 0.2760 - accuracy: 0.9259 - val_loss: 0.2038 - val_accuracy: 0.9213
# Epoch 26/30
# 9/9 [==============================] - 75s 8s/step - loss: 0.2950 - accuracy: 0.9111 - val_loss: 0.1902 - val_accuracy: 0.9583
# Epoch 27/30
# 9/9 [==============================] - 82s 9s/step - loss: 0.3519 - accuracy: 0.8963 - val_loss: 0.1434 - val_accuracy: 0.9769
# Epoch 28/30
# 9/9 [==============================] - 79s 9s/step - loss: 0.2207 - accuracy: 0.9407 - val_loss: 0.1254 - val_accuracy: 0.9537
# Epoch 29/30
# 9/9 [==============================] - 75s 8s/step - loss: 0.2816 - accuracy: 0.9148 - val_loss: 0.1670 - val_accuracy: 0.9491
# Epoch 30/30
# 9/9 [==============================] - 75s 8s/step - loss: 0.2240 - accuracy: 0.9407 - val_loss: 0.1991 - val_accuracy: 0.9444

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('FOODS.h5')
model_CNN=models.load_model('FOODS.h5')
test_image = image.load_img('/content/drive/MyDrive/MONAN/1/BANHMI.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,256,256,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [0]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('FOODS.h5')
model_CNN=models.load_model('FOODS.h5')
test_image = image.load_img('/content/drive/MyDrive/MONAN/1/CAKHO.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,256,256,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [6]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('FOODS.h5')
model_CNN=models.load_model('FOODS.h5')
test_image = image.load_img('/content/drive/MyDrive/MONAN/1/COMTAM.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,256,256,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [8]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('FOODS.h5')
model_CNN=models.load_model('FOODS.h5')
test_image = image.load_img('/content/drive/MyDrive/MONAN/1/GACHIEN.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,256,256,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f3b94317560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [9]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('FOODS.h5')
model_CNN=models.load_model('FOODS.h5')
test_image = image.load_img('/content/drive/MyDrive/MONAN/1/BUNDAU.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,256,256,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f3b9a2d9950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [5]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('FOODS.h5')
model_CNN=models.load_model('FOODS.h5')
test_image = image.load_img('/content/drive/MyDrive/MONAN/1/BANHXEO.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,256,256,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [3]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('FOODS.h5')
model_CNN=models.load_model('FOODS.h5')
test_image = image.load_img('/content/drive/MyDrive/MONAN/1/BANHUOT.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,256,256,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [2]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('FOODS.h5')
model_CNN=models.load_model('FOODS.h5')
test_image = image.load_img('/content/drive/MyDrive/MONAN/1/BANHTRANG.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,256,256,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [1]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('FOODS.h5')
model_CNN=models.load_model('FOODS.h5')
test_image = image.load_img('/content/drive/MyDrive/MONAN/1/BUNBO.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,256,256,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [4]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('FOODS.h5')
model_CNN=models.load_model('FOODS.h5')
test_image = image.load_img('/content/drive/MyDrive/MONAN/1/CHE.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,256,256,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [7]
